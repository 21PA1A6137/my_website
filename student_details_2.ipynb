# %% [markdown]
# <a href="https://colab.research.google.com/github/21PA1A6137/my_website/blob/main/student_details_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('/content/drive/MyDrive/student_details.csv')
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A            87.3                      65.3
# 1        2      F       A            89.0                      92.4
# 2        3      F       A            67.0                      40.2
# 3        4      M       A            71.0                      70.4
# 4        5      M       A            44.0                      65.5
#
#    B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0              40.00        18                                 NO
# 1              21.20         0                                yes
# 2                NaN        13                                yes
# 3              36.47        17                                yes
# 4              42.52        17                                yes
#
#   placement status
# 0       Not placed
# 1           Placed
# 2       Not placed
# 3       Not placed
# 4       Not placed

# %%
df.shape
# Out:
# (117, 9)

# %%
# basic characteristics of data

df.describe()
# Out:
#           Roll No  SSC Percentage  inter_Diploma_percentage  \
# count  117.000000      116.000000                117.000000
# mean    59.000000       80.153362                 80.535299
# std     33.919021        9.462320                 11.818567
# min      1.000000       44.000000                 40.200000
# 25%     30.000000       75.875000                 73.400000
# 50%     59.000000       82.745000                 83.600000
# 75%     88.000000       87.025000                 90.000000
# max    117.000000       93.660000                 96.900000
#
#        B.Tech_percentage    Backlogs
# count         116.000000  117.000000
# mean           62.662672    4.111111
# std            12.591167    6.335148
# min            21.200000    0.000000
# 25%            54.175000    0.000000
# 50%            63.885000    0.000000
# 75%            72.570000    7.000000
# max            88.100000   25.000000

# %%
df.isna().any()
# Out:
# Roll No                               False
# Gender                                False
# Section                               False
# SSC Percentage                         True
# inter_Diploma_percentage              False
# B.Tech_percentage                      True
# Backlogs                              False
# registered_for_ Placement_Training     True
# placement status                      False
# dtype: bool

# %%
df['SSC Percentage'] = df['SSC Percentage'].replace(to_replace=np.nan , value = np.mean(df['SSC Percentage']))
df['B.Tech_percentage'] = df['B.Tech_percentage'].replace(to_replace=np.nan , value = np.mean(df['B.Tech_percentage']))
df['registered_for_ Placement_Training'] = df['registered_for_ Placement_Training'].replace(to_replace = np.nan , value=df['registered_for_ Placement_Training'].mode()[0])
df.head()
# Out:
#    Roll No Gender Section  SSC Percentage  inter_Diploma_percentage  \
# 0        1      M       A            87.3                      65.3
# 1        2      F       A            89.0                      92.4
# 2        3      F       A            67.0                      40.2
# 3        4      M       A            71.0                      70.4
# 4        5      M       A            44.0                      65.5
#
#    B.Tech_percentage  Backlogs registered_for_ Placement_Training  \
# 0          40.000000        18                                 NO
# 1          21.200000         0                                yes
# 2          62.662672        13                                yes
# 3          36.470000        17                                yes
# 4          42.520000        17                                yes
#
#   placement status
# 0       Not placed
# 1           Placed
# 2       Not placed
# 3       Not placed
# 4       Not placed

# %%
df.isna().any()
# Out:
# Roll No                               False
# Gender                                False
# Section                               False
# SSC Percentage                        False
# inter_Diploma_percentage              False
# B.Tech_percentage                     False
# Backlogs                              False
# registered_for_ Placement_Training    False
# placement status                      False
# dtype: bool

# %%
df.dtypes
# Out:
# Roll No                                 int64
# Gender                                 object
# Section                                object
# SSC Percentage                        float64
# inter_Diploma_percentage              float64
# B.Tech_percentage                     float64
# Backlogs                                int64
# registered_for_ Placement_Training     object
# placement status                       object
# dtype: object

# %%
df['Gender'].value_counts()
# Out:
# M    68
# F    49
# Name: Gender, dtype: int64

# %%
df['Section'].value_counts()
# Out:
# A    60
# B    57
# Name: Section, dtype: int64

# %%
df['registered_for_ Placement_Training'].value_counts()
# Out:
# yes    68
# NO     49
# Name: registered_for_ Placement_Training, dtype: int64

# %%
df['placement status'].value_counts()
# Out:
# Not placed    78
# Placed        39
# Name: placement status, dtype: int64

# %%
cut_counts = df['Gender'].value_counts()
fig = px.bar(x=cut_counts.index , y=cut_counts.values , width=600)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sec_count = df['Section'].value_counts()
fig_1 = px.bar(x=sec_count.index , y=sec_count.values , width=600)
fig_1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
rpt_count = df['registered_for_ Placement_Training'].value_counts()
fig_2 = px.bar(x=rpt_count.index , y=rpt_count.values , width=600)
fig_2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
ps_count = df['placement status'].value_counts()
fig_3 = px.bar(x=ps_count.index , y = ps_count.values , width=600)
fig_3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pd.crosstab(index=df['Gender'],columns = df['placement status'])
# Out:
# placement status  Not placed  Placed
# Gender
# F                         20      29
# M                         58      10

# %%
pd.crosstab(index=df['Gender'],columns = [df['registered_for_ Placement_Training'],df['placement status']])
# Out:
# registered_for_ Placement_Training         NO               yes
# placement status                   Not placed Placed Not placed Placed
# Gender
# F                                           9     10         11     19
# M                                          27      3         31      7

# %%
pd.crosstab(index=df['Gender'],columns=df['registered_for_ Placement_Training'])
# Out:
# registered_for_ Placement_Training  NO  yes
# Gender
# F                                   19   30
# M                                   30   38

# %%
pd.pivot_table(df,values='B.Tech_percentage',index='Gender',columns='placement status',aggfunc=np.mean)
# Out:
# placement status  Not placed     Placed
# Gender
# F                  66.175634  73.531379
# M                  54.825345  69.574000

# %%
df_encoded = pd.get_dummies(df['Gender'])
df_encoded
# Out:
#      F  M
# 0    0  1
# 1    1  0
# 2    1  0
# 3    0  1
# 4    0  1
# ..  .. ..
# 112  0  1
# 113  0  1
# 114  0  1
# 115  0  1
# 116  0  1
#
# [117 rows x 2 columns]

# %%
X=df[["Gender","Section","SSC Percentage","inter_Diploma_percentage","B.Tech_percentage","Backlogs","registered_for_ Placement_Training"]].values

# %%
y=df["placement status"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %%
print(X.shape)
print(y.shape)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (117, 7)
# (117,)
# (93, 7)
# (24, 7)
# (93,)
# (24,)
